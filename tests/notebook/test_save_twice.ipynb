# %% [markdown]
# Verify that if we save the same node twice, it is the same artifact

# %%
import lineapy

# %%
x = 100

# %%
res1 = lineapy.save(x, "x")

# %%
res2 = lineapy.save(x, "x")
# Out:
# [12:34:53] ERROR    Artifact could not be saved.                                                                                                                                 tracer.py:157

# %%
assert res1.node_id == res2.node_id
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7m/28yvg94536z71zcqnlx9smkh0000gn/T/ipykernel_5926/1857875313.py in <module>
#       1 import lineapy.editors.ipython
# ----> 2 lineapy.editors.ipython._end_cell()
#
# ~/p/lineapy/lineapy/editors/ipython.py in _end_cell()
#     147     get_cell_path(location).write_text(code)
#     148
# --> 149     last_node = transform(code, location, STATE.tracer)
#     150     if STATE.visualize_display_handle:
#     151         STATE.visualize_display_handle.update(
#
# ~/p/lineapy/lineapy/transformer/node_transformer.py in transform(code, location, tracer)
#      94         SourceGiver().transform(tree)
#      95
# ---> 96     node_transformer.visit(tree)
#      97
#      98     tracer.db.commit()
#
# /opt/homebrew/Caskroom/miniconda/base/envs/lineapy/lib/python3.9/ast.py in visit(self, node)
#     405         method = 'visit_' + node.__class__.__name__
#     406         visitor = getattr(self, method, self.generic_visit)
# --> 407         return visitor(node)
#     408
#     409     def generic_visit(self, node):
#
# ~/p/lineapy/lineapy/transformer/node_transformer.py in visit_Module(self, node)
#     213     def visit_Module(self, node: ast.Module) -> Any:
#     214         for stmt in node.body:
# --> 215             self.last_statement_result = self.visit(stmt)
#     216
#     217     def visit_Expr(self, node: ast.Expr) -> Node:
#
# /opt/homebrew/Caskroom/miniconda/base/envs/lineapy/lib/python3.9/ast.py in visit(self, node)
#     405         method = 'visit_' + node.__class__.__name__
#     406         visitor = getattr(self, method, self.generic_visit)
# --> 407         return visitor(node)
#     408
#     409     def generic_visit(self, node):
#
# ~/p/lineapy/lineapy/transformer/node_transformer.py in visit_Assert(self, node)
#     220     def visit_Assert(self, node: ast.Assert) -> None:
#     221
# --> 222         args = [self.visit(node.test)]
#     223         if node.msg:
#     224             args.append(self.visit(node.msg))
#
# /opt/homebrew/Caskroom/miniconda/base/envs/lineapy/lib/python3.9/ast.py in visit(self, node)
#     405         method = 'visit_' + node.__class__.__name__
#     406         visitor = getattr(self, method, self.generic_visit)
# --> 407         return visitor(node)
#     408
#     409     def generic_visit(self, node):
#
# ~/p/lineapy/lineapy/transformer/node_transformer.py in visit_Compare(self, node)
#     509         # ast.Compare can have an arbitrary number of operators
#     510         # e.g., a < b <= c
# --> 511         left = self.visit(node.left)
#     512         for i in range(len(node.ops)):
#     513             op = node.ops[i]
#
# /opt/homebrew/Caskroom/miniconda/base/envs/lineapy/lib/python3.9/ast.py in visit(self, node)
#     405         method = 'visit_' + node.__class__.__name__
#     406         visitor = getattr(self, method, self.generic_visit)
# --> 407         return visitor(node)
#     408
#     409     def generic_visit(self, node):
#
# ~/p/lineapy/lineapy/transformer/node_transformer.py in visit_Attribute(self, node)
#     578     def visit_Attribute(self, node: ast.Attribute) -> CallNode:
#     579
# --> 580         return self.tracer.call(
#     581             self.tracer.lookup_node(GETATTR),
#     582             self.get_source(node),
#
# ~/p/lineapy/lineapy/instrumentation/tracer.py in call(self, function_node, source_location, *arguments, **keyword_arguments)
#     400             implicit_dependencies=[],
#     401         )
# --> 402         self.process_node(node)
#     403         return node
#     404
#
# ~/p/lineapy/lineapy/instrumentation/tracer.py in process_node(self, node)
#     151         ##
#     152         try:
# --> 153             side_effects = self.executor.execute_node(
#     154                 node, {k: v.id for k, v in self.variable_name_to_node.items()}
#     155             )
#
# ~/p/lineapy/lineapy/execution/executor.py in execute_node(self, node, variables)
#     180             )
#     181
# --> 182         res = self._execute(node, default_changes, variables)
#     183         value = res.value
#     184         self._id_to_value[node.id] = value
#
# /opt/homebrew/Caskroom/miniconda/base/envs/lineapy/lib/python3.9/functools.py in _method(*args, **kwargs)
#     912         def _method(*args, **kwargs):
#     913             method = self.dispatcher.dispatch(args[0].__class__)
# --> 914             return method.__get__(obj, cls)(*args, **kwargs)
#     915
#     916         _method.__isabstractmethod__ = self.__isabstractmethod__
#
# ~/p/lineapy/lineapy/execution/executor.py in _execute_call(self, node, changes, variables)
#     266
#     267         # Set up our execution context, with our globals and node
# --> 268         set_context(self, variables, node)
#     269
#     270         try:
#
# ~/p/lineapy/lineapy/execution/context.py in set_context(executor, variables, node)
#      71     # The subsequent times, we only use those that were recorded
#      72     input_node_ids = variables or node.global_reads
# ---> 73     input_globals = {
#      74         k: executor._id_to_value[id_] for k, id_ in input_node_ids.items()
#      75     }
#
# ~/p/lineapy/lineapy/execution/context.py in <dictcomp>(.0)
#      72     input_node_ids = variables or node.global_reads
#      73     input_globals = {
# ---> 74         k: executor._id_to_value[id_] for k, id_ in input_node_ids.items()
#      75     }
#      76
#
# KeyError: '41b159dc-5ae7-4d0d-b93c-f15e951d50fa'
